# %%
import pandas as pd

# %%
df = pd.read_json("/Users/ds/documents/datascience/final_project/congress_tweets/congresstweets-automator/data/users-filtered.json", encoding='utf-8')

# %%
df.head()
# Out:
#                                             accounts chamber   id  \
# 0  {u'office': [{u'screen_name': u'BlueCollarDems...   house  NaN
# 1  {u'office': [{u'screen_name': u'HouseBlueDogs'...   house  NaN
# 2  {u'office': [{u'screen_name': u'CAPAC', u'id':...   house  NaN
# 3  {u'office': [{u'screen_name': u'OfficialCBC', ...   house  NaN
# 4  {u'office': [{u'screen_name': u'HealthCaucus',...   house  NaN
#
#                                           name party state    type
# 0                           Blue Collar Caucus     D   NaN  caucus
# 1                           Blue Dog Coalition     D   NaN  caucus
# 2  Congressional Asian Pacific American Caucus     D   NaN  caucus
# 3                   Congressional Black Caucus     D   NaN  caucus
# 4                  Congressional Health Caucus     R   NaN  caucus

# %%
df.to_csv('meta_raw.csv', encoding='utf-8')

# %%
df1 = df[df['type'] == "committee"]

# %%
party = pd.read_csv('party.csv', encoding='utf-8')

# %%
party.drop('Unnamed: 0', 1, inplace=True)

# %%
df = df[df['type'] != "committee"]

# %%
df = df[df['type'] != "party"]

# %%
df1.reset_index(drop=True, inplace=True)

# %%
df1.to_csv('committee.csv', index=False, encoding='utf-8')

# %%
df1.head()
# Out:
#                                             accounts chamber  \
# 0  {u'office': [{u'party': u'R', u'screen_name': ...   house
# 1  {u'office': [{u'party': u'D', u'screen_name': ...   house
# 2  {u'office': [{u'party': u'D', u'screen_name': ...   house
# 3  {u'office': [{u'party': u'D', u'screen_name': ...   house
# 4  {u'office': [{u'party': u'D', u'screen_name': ...   house
#
#                                                   id  \
# 0  {u'tag': u'agriculture', u'house_committee_id'...
# 1  {u'tag': u'appropriations', u'house_committee_...
# 2  {u'tag': u'armedservices', u'house_committee_i...
# 3  {u'tag': u'edworkforce', u'house_committee_id'...
# 4  {u'tag': u'energycommerce', u'house_committee_...
#
#                                              name party state       type
# 0                  House Committee on Agriculture   NaN   NaN  committee
# 1               House Committee on Appropriations   NaN   NaN  committee
# 2               House Committee on Armed Services   NaN   NaN  committee
# 3  House Committee on Education and the Workforce   NaN   NaN  committee
# 4          House Committee on Energy and Commerce   NaN   NaN  committee

# %%
count = 0

for x in df1.accounts:
    x['index'] = count
    count = count + 1

# %%
df1.loc[1,'accounts']
# Out:
# {'index': 1,
#  u'office': [{u'id': 30912937,
#    u'id_str': u'30912937',
#    u'party': u'D',
#    u'screen_name': u'AppropsDems'},
#   {u'id': 301549400,
#    u'id_str': u'301549400',
#    u'party': u'R',
#    u'screen_name': u'HouseAppropsGOP'}]}

# %%
comm = []

for x in df1.accounts:
    if len(x['office']) == 1:
        comm.append([x['index'], x['office'][0]['party'], x['office'][0]['screen_name']])
    else:
        comm.append([x['index'], x['office'][0]['party'], x['office'][0]['screen_name']])
        comm.append([x['index'], x['office'][1]['party'], x['office'][1]['screen_name']])

# %%
df1['index'] = df1.index

# %%
df2 = pd.DataFrame(comm, columns = ['index', 'party1', 'screen_name'])

# %%
df2.head()
# Out:
#    index party1      screen_name
# 0      0      R      HouseAgNews
# 1      1      D      AppropsDems
# 2      1      R  HouseAppropsGOP
# 3      2      D    HASCDemocrats
# 4      2      R  HASCRepublicans

# %%
df1.head()
# Out:
#                                             accounts chamber  \
# 0  {u'index': 0, u'office': [{u'party': u'R', u's...   house
# 1  {u'index': 1, u'office': [{u'party': u'D', u's...   house
# 2  {u'index': 2, u'office': [{u'party': u'D', u's...   house
# 3  {u'index': 3, u'office': [{u'party': u'D', u's...   house
# 4  {u'index': 4, u'office': [{u'party': u'D', u's...   house
#
#                                                   id  \
# 0  {u'tag': u'agriculture', u'house_committee_id'...
# 1  {u'tag': u'appropriations', u'house_committee_...
# 2  {u'tag': u'armedservices', u'house_committee_i...
# 3  {u'tag': u'edworkforce', u'house_committee_id'...
# 4  {u'tag': u'energycommerce', u'house_committee_...
#
#                                              name party state       type  \
# 0                  House Committee on Agriculture   NaN   NaN  committee
# 1               House Committee on Appropriations   NaN   NaN  committee
# 2               House Committee on Armed Services   NaN   NaN  committee
# 3  House Committee on Education and the Workforce   NaN   NaN  committee
# 4          House Committee on Energy and Commerce   NaN   NaN  committee
#
#    index
# 0      0
# 1      1
# 2      2
# 3      3
# 4      4

# %%
df2.head()
# Out:
#    index party1      screen_name
# 0      0      R      HouseAgNews
# 1      1      D      AppropsDems
# 2      1      R  HouseAppropsGOP
# 3      2      D    HASCDemocrats
# 4      2      R  HASCRepublicans

# %%
df1 = pd.DataFrame.merge(df1, df2, how="left", on='index')

# %%
df1.head()
# Out:
#                                             accounts chamber  \
# 0  {u'index': 0, u'office': [{u'party': u'R', u's...   house
# 1  {u'index': 1, u'office': [{u'party': u'D', u's...   house
# 2  {u'index': 1, u'office': [{u'party': u'D', u's...   house
# 3  {u'index': 2, u'office': [{u'party': u'D', u's...   house
# 4  {u'index': 2, u'office': [{u'party': u'D', u's...   house
#
#                                                   id  \
# 0  {u'tag': u'agriculture', u'house_committee_id'...
# 1  {u'tag': u'appropriations', u'house_committee_...
# 2  {u'tag': u'appropriations', u'house_committee_...
# 3  {u'tag': u'armedservices', u'house_committee_i...
# 4  {u'tag': u'armedservices', u'house_committee_i...
#
#                                 name party state       type  index party1  \
# 0     House Committee on Agriculture   NaN   NaN  committee      0      R
# 1  House Committee on Appropriations   NaN   NaN  committee      1      D
# 2  House Committee on Appropriations   NaN   NaN  committee      1      R
# 3  House Committee on Armed Services   NaN   NaN  committee      2      D
# 4  House Committee on Armed Services   NaN   NaN  committee      2      R
#
#        screen_name
# 0      HouseAgNews
# 1      AppropsDems
# 2  HouseAppropsGOP
# 3    HASCDemocrats
# 4  HASCRepublicans

# %%
df1.shape
# Out:
# (55, 10)

# %%
df1.drop('party', 1, inplace=True)

# %%
df1.drop(['index'], 1, inplace=True)

# %%
df1.rename(columns={'party1': 'party'}, inplace=True)

# %%
df1.head()
# Out:
#                                             accounts chamber  \
# 0  {u'index': 0, u'office': [{u'party': u'R', u's...   house
# 1  {u'index': 1, u'office': [{u'party': u'D', u's...   house
# 2  {u'index': 1, u'office': [{u'party': u'D', u's...   house
# 3  {u'index': 2, u'office': [{u'party': u'D', u's...   house
# 4  {u'index': 2, u'office': [{u'party': u'D', u's...   house
#
#                                                   id  \
# 0  {u'tag': u'agriculture', u'house_committee_id'...
# 1  {u'tag': u'appropriations', u'house_committee_...
# 2  {u'tag': u'appropriations', u'house_committee_...
# 3  {u'tag': u'armedservices', u'house_committee_i...
# 4  {u'tag': u'armedservices', u'house_committee_i...
#
#                                 name state       type party      screen_name
# 0     House Committee on Agriculture   NaN  committee     R      HouseAgNews
# 1  House Committee on Appropriations   NaN  committee     D      AppropsDems
# 2  House Committee on Appropriations   NaN  committee     R  HouseAppropsGOP
# 3  House Committee on Armed Services   NaN  committee     D    HASCDemocrats
# 4  House Committee on Armed Services   NaN  committee     R  HASCRepublicans

# %%
df.shape
# Out:
# (552, 7)

# %%
df.head()
# Out:
#                                             accounts chamber   id  \
# 0  {u'office': [{u'screen_name': u'BlueCollarDems...   house  NaN
# 1  {u'office': [{u'screen_name': u'HouseBlueDogs'...   house  NaN
# 2  {u'office': [{u'screen_name': u'CAPAC', u'id':...   house  NaN
# 3  {u'office': [{u'screen_name': u'OfficialCBC', ...   house  NaN
# 4  {u'office': [{u'screen_name': u'HealthCaucus',...   house  NaN
#
#                                           name party state    type
# 0                           Blue Collar Caucus     D   NaN  caucus
# 1                           Blue Dog Coalition     D   NaN  caucus
# 2  Congressional Asian Pacific American Caucus     D   NaN  caucus
# 3                   Congressional Black Caucus     D   NaN  caucus
# 4                  Congressional Health Caucus     R   NaN  caucus

# %%
count = 0

for x in df.accounts:
    x['index'] = count
    count = count + 1

# %%
df.reset_index(inplace=True, drop=True)

# %%
handles = []


for item in df.accounts:
    if 'office' in item.keys() and 'campaign' in item.keys():
        if len(item['office']) > 1 and len(item['campaign']) > 1:
            handles.append([item['index'], item['office'][0]['screen_name'], 'no'])
            handles.append([item['index'], item['office'][1]['screen_name'], 'no'])
            handles.append([item['index'], item['campaign'][0]['screen_name'], 'yes'])
            handles.append([item['index'], item['campaign'][1]['screen_name'], 'yes'])
        elif len(item['office']) > 1 and len(item['campaign']) == 1:
            handles.append([item['index'], item['office'][0]['screen_name'], 'no'])
            handles.append([item['index'], item['office'][1]['screen_name'], 'no'])
            handles.append([item['index'], item['campaign'][0]['screen_name'], 'yes'])
        elif len(item['office']) == 1 and len(item['campaign']) > 1:
            handles.append([item['index'], item['office'][0]['screen_name'], 'no'])
            handles.append([item['index'], item['campaign'][0]['screen_name'], 'yes'])
            handles.append([item['index'], item['campaign'][1]['screen_name'], 'yes'])
        elif len(item['office']) == 1 and len(item['campaign']) == 1:
            handles.append([item['index'], item['office'][0]['screen_name'], 'no'])
            handles.append([item['index'], item['campaign'][0]['screen_name'], 'yes'])
        elif len(item['office']) == 0 and len(item['campaign']) == 1:
            handles.append([item['index'], item['campaign'][0]['screen_name'], 'yes'])
        elif len(item['office']) == 1 and len(item['campaign']) == 0:
            handles.append([item['index'], item['office'][0]['screen_name'], 'no'])
    elif 'office' in item.keys():
        if len(item['office']) > 1:
            handles.append([item['index'], item['office'][0]['screen_name'], 'no'])
            handles.append([item['index'], item['office'][1]['screen_name'], 'no'])
        else:
            handles.append([item['index'], item['office'][0]['screen_name'], 'no'])
    else:
        if len(item['campaign']) > 1:
            handles.append([item['index'], item['campaign'][0]['screen_name'], 'yes'])
            handles.append([item['index'], item['campaign'][1]['screen_name'], 'yes'])
        else:
            handles.append([item['index'], item['campaign'][0]['screen_name'], 'yes'])
        
len(handles)
# Out:
# 1007

# %%
df6 = pd.DataFrame(handles, columns = ['index', 'screen_name', 'ch'])

# %%
df6.shape
# Out:
# (1007, 3)

# %%
df.head()
# Out:
#                                             accounts chamber   id  \
# 0  {u'index': 0, u'office': [{u'screen_name': u'B...   house  NaN
# 1  {u'index': 1, u'office': [{u'screen_name': u'H...   house  NaN
# 2  {u'index': 2, u'office': [{u'screen_name': u'C...   house  NaN
# 3  {u'index': 3, u'office': [{u'screen_name': u'O...   house  NaN
# 4  {u'index': 4, u'office': [{u'screen_name': u'H...   house  NaN
#
#                                           name party state    type
# 0                           Blue Collar Caucus     D   NaN  caucus
# 1                           Blue Dog Coalition     D   NaN  caucus
# 2  Congressional Asian Pacific American Caucus     D   NaN  caucus
# 3                   Congressional Black Caucus     D   NaN  caucus
# 4                  Congressional Health Caucus     R   NaN  caucus

# %%
df['index'] = df.index
df.head()
# Out:
#                                             accounts chamber   id  \
# 0  {u'index': 0, u'office': [{u'screen_name': u'B...   house  NaN
# 1  {u'index': 1, u'office': [{u'screen_name': u'H...   house  NaN
# 2  {u'index': 2, u'office': [{u'screen_name': u'C...   house  NaN
# 3  {u'index': 3, u'office': [{u'screen_name': u'O...   house  NaN
# 4  {u'index': 4, u'office': [{u'screen_name': u'H...   house  NaN
#
#                                           name party state    type  index
# 0                           Blue Collar Caucus     D   NaN  caucus      0
# 1                           Blue Dog Coalition     D   NaN  caucus      1
# 2  Congressional Asian Pacific American Caucus     D   NaN  caucus      2
# 3                   Congressional Black Caucus     D   NaN  caucus      3
# 4                  Congressional Health Caucus     R   NaN  caucus      4

# %%
df7 = pd.DataFrame.merge(df6, df, how='left', on='index')

# %%
df7.head()
# Out:
#    index     screen_name  ch  \
# 0      0  BlueCollarDems  no
# 1      1   HouseBlueDogs  no
# 2      2           CAPAC  no
# 3      3     OfficialCBC  no
# 4      4    HealthCaucus  no
#
#                                             accounts chamber   id  \
# 0  {u'index': 0, u'office': [{u'screen_name': u'B...   house  NaN
# 1  {u'index': 1, u'office': [{u'screen_name': u'H...   house  NaN
# 2  {u'index': 2, u'office': [{u'screen_name': u'C...   house  NaN
# 3  {u'index': 3, u'office': [{u'screen_name': u'O...   house  NaN
# 4  {u'index': 4, u'office': [{u'screen_name': u'H...   house  NaN
#
#                                           name party state    type
# 0                           Blue Collar Caucus     D   NaN  caucus
# 1                           Blue Dog Coalition     D   NaN  caucus
# 2  Congressional Asian Pacific American Caucus     D   NaN  caucus
# 3                   Congressional Black Caucus     D   NaN  caucus
# 4                  Congressional Health Caucus     R   NaN  caucus

# %%
df1.head()
# Out:
#                                             accounts chamber  \
# 0  {u'index': 0, u'office': [{u'party': u'R', u's...   house
# 1  {u'index': 1, u'office': [{u'party': u'D', u's...   house
# 2  {u'index': 1, u'office': [{u'party': u'D', u's...   house
# 3  {u'index': 2, u'office': [{u'party': u'D', u's...   house
# 4  {u'index': 2, u'office': [{u'party': u'D', u's...   house
#
#                                                   id  \
# 0  {u'tag': u'agriculture', u'house_committee_id'...
# 1  {u'tag': u'appropriations', u'house_committee_...
# 2  {u'tag': u'appropriations', u'house_committee_...
# 3  {u'tag': u'armedservices', u'house_committee_i...
# 4  {u'tag': u'armedservices', u'house_committee_i...
#
#                                 name state       type party      screen_name
# 0     House Committee on Agriculture   NaN  committee     R      HouseAgNews
# 1  House Committee on Appropriations   NaN  committee     D      AppropsDems
# 2  House Committee on Appropriations   NaN  committee     R  HouseAppropsGOP
# 3  House Committee on Armed Services   NaN  committee     D    HASCDemocrats
# 4  House Committee on Armed Services   NaN  committee     R  HASCRepublicans

# %%
df1['ch'] = 'no'

# %%
df1.head()
# Out:
#                                             accounts chamber  \
# 0  {u'index': 0, u'office': [{u'party': u'R', u's...   house
# 1  {u'index': 1, u'office': [{u'party': u'D', u's...   house
# 2  {u'index': 1, u'office': [{u'party': u'D', u's...   house
# 3  {u'index': 2, u'office': [{u'party': u'D', u's...   house
# 4  {u'index': 2, u'office': [{u'party': u'D', u's...   house
#
#                                                   id  \
# 0  {u'tag': u'agriculture', u'house_committee_id'...
# 1  {u'tag': u'appropriations', u'house_committee_...
# 2  {u'tag': u'appropriations', u'house_committee_...
# 3  {u'tag': u'armedservices', u'house_committee_i...
# 4  {u'tag': u'armedservices', u'house_committee_i...
#
#                                 name state       type party      screen_name  \
# 0     House Committee on Agriculture   NaN  committee     R      HouseAgNews
# 1  House Committee on Appropriations   NaN  committee     D      AppropsDems
# 2  House Committee on Appropriations   NaN  committee     R  HouseAppropsGOP
# 3  House Committee on Armed Services   NaN  committee     D    HASCDemocrats
# 4  House Committee on Armed Services   NaN  committee     R  HASCRepublicans
#
#    ch
# 0  no
# 1  no
# 2  no
# 3  no
# 4  no

# %%
df7.drop('index', 1, inplace=True)

# %%
party.head()
# Out:
#       screen_name                                           accounts chamber  \
# 0    DemCloakroom  {u'index': 0, u'campaign': [{u'screen_name': u...   house
# 1  HouseDemocrats  {u'index': 0, u'campaign': [{u'screen_name': u...   house
# 2            dccc  {u'index': 0, u'campaign': [{u'screen_name': u...   house
# 3      GOPEspanol  {u'index': 1, u'campaign': [{u'screen_name': u...   house
# 4       GOPpolicy  {u'index': 1, u'campaign': [{u'screen_name': u...   house
#
#    id         name party  state   type   ch
# 0 NaN    Democrats     D    NaN  party  yes
# 1 NaN    Democrats     D    NaN  party   no
# 2 NaN    Democrats     D    NaN  party  yes
# 3 NaN  Republicans     R    NaN  party   no
# 4 NaN  Republicans     R    NaN  party   no

# %%
df1
# Out:
#                                              accounts chamber  \
# 0   {u'index': 0, u'office': [{u'party': u'R', u's...   house
# 1   {u'index': 1, u'office': [{u'party': u'D', u's...   house
# 2   {u'index': 1, u'office': [{u'party': u'D', u's...   house
# 3   {u'index': 2, u'office': [{u'party': u'D', u's...   house
# 4   {u'index': 2, u'office': [{u'party': u'D', u's...   house
# 5   {u'index': 3, u'office': [{u'party': u'D', u's...   house
# 6   {u'index': 3, u'office': [{u'party': u'D', u's...   house
# 7   {u'index': 4, u'office': [{u'party': u'D', u's...   house
# 8   {u'index': 4, u'office': [{u'party': u'D', u's...   house
# 9   {u'index': 5, u'office': [{u'party': u'D', u's...   house
# 10  {u'index': 5, u'office': [{u'party': u'D', u's...   house
# 11  {u'index': 6, u'office': [{u'party': u'D', u's...   house
# 12  {u'index': 6, u'office': [{u'party': u'D', u's...   house
# 13  {u'index': 7, u'office': [{u'party': u'D', u's...   house
# 14  {u'index': 7, u'office': [{u'party': u'D', u's...   house
# 15  {u'index': 8, u'office': [{u'party': u'D', u's...   house
# 16  {u'index': 8, u'office': [{u'party': u'D', u's...   house
# 17  {u'index': 9, u'office': [{u'party': u'D', u's...   house
# 18  {u'index': 9, u'office': [{u'party': u'D', u's...   house
# 19  {u'index': 10, u'office': [{u'party': u'D', u'...   house
# 20  {u'index': 10, u'office': [{u'party': u'D', u'...   house
# 21  {u'index': 11, u'office': [{u'party': u'R', u'...   house
# 22  {u'index': 12, u'office': [{u'party': u'D', u'...   house
# 23  {u'index': 12, u'office': [{u'party': u'D', u'...   house
# 24  {u'index': 13, u'office': [{u'party': u'R', u'...   house
# 25  {u'index': 14, u'office': [{u'party': u'D', u'...   house
# 26  {u'index': 14, u'office': [{u'party': u'D', u'...   house
# 27  {u'index': 15, u'office': [{u'party': u'D', u'...   house
# 28  {u'index': 15, u'office': [{u'party': u'D', u'...   house
# 29  {u'index': 16, u'office': [{u'party': u'D', u'...   house
# 30  {u'index': 16, u'office': [{u'party': u'D', u'...   house
# 31  {u'index': 17, u'office': [{u'party': u'D', u'...   house
# 32  {u'index': 17, u'office': [{u'party': u'D', u'...   house
# 33  {u'index': 18, u'office': [{u'party': u'D', u'...   house
# 34  {u'index': 18, u'office': [{u'party': u'D', u'...   house
# 35  {u'index': 19, u'office': [{u'party': u'N/A', ...   joint
# 36  {u'index': 20, u'office': [{u'party': u'D', u'...   joint
# 37  {u'index': 20, u'office': [{u'party': u'D', u'...   joint
# 38  {u'index': 21, u'office': [{u'party': u'R', u'...  senate
# 39  {u'index': 22, u'office': [{u'party': u'D', u'...  senate
# 40  {u'index': 23, u'office': [{u'party': u'R', u'...  senate
# 41  {u'index': 24, u'office': [{u'party': u'R', u'...  senate
# 42  {u'index': 25, u'office': [{u'party': u'R', u'...  senate
# 43  {u'index': 26, u'office': [{u'party': u'D', u'...  senate
# 44  {u'index': 26, u'office': [{u'party': u'D', u'...  senate
# 45  {u'index': 27, u'office': [{u'party': u'D', u'...  senate
# 46  {u'index': 27, u'office': [{u'party': u'D', u'...  senate
# 47  {u'index': 28, u'office': [{u'party': u'R', u'...  senate
# 48  {u'index': 29, u'office': [{u'party': u'R', u'...  senate
# 49  {u'index': 30, u'office': [{u'party': u'R', u'...  senate
# 50  {u'index': 31, u'office': [{u'party': u'R', u'...  senate
# 51  {u'index': 32, u'office': [{u'party': u'R', u'...  senate
# 52  {u'index': 33, u'office': [{u'party': u'R', u'...  senate
# 53  {u'index': 34, u'office': [{u'party': u'R', u'...  senate
# 54  {u'index': 35, u'office': [{u'party': u'R', u'...  senate
#
#                                                    id  \
# 0   {u'tag': u'agriculture', u'house_committee_id'...
# 1   {u'tag': u'appropriations', u'house_committee_...
# 2   {u'tag': u'appropriations', u'house_committee_...
# 3   {u'tag': u'armedservices', u'house_committee_i...
# 4   {u'tag': u'armedservices', u'house_committee_i...
# 5   {u'tag': u'edworkforce', u'house_committee_id'...
# 6   {u'tag': u'edworkforce', u'house_committee_id'...
# 7   {u'tag': u'energycommerce', u'house_committee_...
# 8   {u'tag': u'energycommerce', u'house_committee_...
# 9   {u'tag': u'financialservices', u'house_committ...
# 10  {u'tag': u'financialservices', u'house_committ...
# 11  {u'tag': u'foreignaffairs', u'house_committee_...
# 12  {u'tag': u'foreignaffairs', u'house_committee_...
# 13  {u'tag': u'homeland', u'house_committee_id': u...
# 14  {u'tag': u'homeland', u'house_committee_id': u...
# 15  {u'tag': u'cha', u'house_committee_id': u'HA',...
# 16  {u'tag': u'cha', u'house_committee_id': u'HA',...
# 17  {u'tag': u'naturalresources', u'house_committe...
# 18  {u'tag': u'naturalresources', u'house_committe...
# 19  {u'tag': u'oversight', u'house_committee_id': ...
# 20  {u'tag': u'oversight', u'house_committee_id': ...
# 21  {u'tag': u'rules', u'house_committee_id': u'RU...
# 22  {u'tag': u'science', u'house_committee_id': u'...
# 23  {u'tag': u'science', u'house_committee_id': u'...
# 24  {u'tag': u'smallbusiness', u'house_committee_i...
# 25  {u'tag': u'transportation', u'house_committee_...
# 26  {u'tag': u'transportation', u'house_committee_...
# 27  {u'tag': u'veterans', u'house_committee_id': u...
# 28  {u'tag': u'veterans', u'house_committee_id': u...
# 29  {u'tag': u'waysandmeans', u'house_committee_id...
# 30  {u'tag': u'waysandmeans', u'house_committee_id...
# 31  {u'tag': u'budget', u'house_committee_id': u'B...
# 32  {u'tag': u'budget', u'house_committee_id': u'B...
# 33  {u'tag': u'judiciary', u'house_committee_id': ...
# 34  {u'tag': u'judiciary', u'house_committee_id': ...
# 35  {u'tag': u'jct', u'thomas_id': u'JSTX', u'sena...
# 36  {u'tag': u'jec', u'thomas_id': u'JSEC', u'sena...
# 37  {u'tag': u'jec', u'thomas_id': u'JSEC', u'sena...
# 38  {u'tag': u'agriculture', u'thomas_id': u'SSAS2...
# 39  {u'tag': u'appropriations', u'thomas_id': u'SS...
# 40  {u'tag': u'armed-services', u'thomas_id': u'SS...
# 41  {u'tag': u'banking', u'thomas_id': u'SSBK', u'...
# 42  {u'tag': u'commerce', u'thomas_id': u'SSCM', u...
# 43  {u'tag': u'energy', u'thomas_id': u'SSEG', u's...
# 44  {u'tag': u'energy', u'thomas_id': u'SSEG', u's...
# 45  {u'tag': u'epw', u'thomas_id': u'SSEV', u'sena...
# 46  {u'tag': u'epw', u'thomas_id': u'SSEV', u'sena...
# 47  {u'tag': u'finance', u'thomas_id': u'SSFI', u'...
# 48  {u'tag': u'help', u'thomas_id': u'SSHR', u'sen...
# 49  {u'tag': u'indian', u'thomas_id': u'SLIA', u's...
# 50  {u'tag': u'sbc', u'thomas_id': u'SSSB', u'sena...
# 51  {u'tag': u'veterans', u'thomas_id': u'SSVA', u...
# 52  {u'tag': u'budget', u'thomas_id': u'SSBU', u's...
# 53  {u'tag': u'judiciary', u'thomas_id': u'SSJU', ...
# 54  {u'tag': u'aging', u'thomas_id': u'SPAG', u'se...
#
#                                                  name state       type party  \
# 0                      House Committee on Agriculture   NaN  committee     R
# 1                   House Committee on Appropriations   NaN  committee     D
# 2                   House Committee on Appropriations   NaN  committee     R
# 3                   House Committee on Armed Services   NaN  committee     D
# 4                   House Committee on Armed Services   NaN  committee     R
# 5      House Committee on Education and the Workforce   NaN  committee     D
# 6      House Committee on Education and the Workforce   NaN  committee     R
# 7              House Committee on Energy and Commerce   NaN  committee     D
# 8              House Committee on Energy and Commerce   NaN  committee     R
# 9               House Committee on Financial Services   NaN  committee     D
# 10              House Committee on Financial Services   NaN  committee     R
# 11                 House Committee on Foreign Affairs   NaN  committee     D
# 12                 House Committee on Foreign Affairs   NaN  committee     R
# 13               House Committee on Homeland Security   NaN  committee     D
# 14               House Committee on Homeland Security   NaN  committee     R
# 15            House Committee on House Administration   NaN  committee     D
# 16            House Committee on House Administration   NaN  committee     R
# 17               House Committee on Natural Resources   NaN  committee     D
# 18               House Committee on Natural Resources   NaN  committee     R
# 19  House Committee on Oversight and Government Re...   NaN  committee     D
# 20  House Committee on Oversight and Government Re...   NaN  committee     R
# 21                           House Committee on Rules   NaN  committee     R
# 22  House Committee on Science, Space, and Technology   NaN  committee     D
# 23  House Committee on Science, Space, and Technology   NaN  committee     R
# 24                  House Committee on Small Business   NaN  committee     R
# 25  House Committee on Transportation and Infrastr...   NaN  committee     D
# 26  House Committee on Transportation and Infrastr...   NaN  committee     R
# 27               House Committee on Veterans' Affairs   NaN  committee     D
# 28               House Committee on Veterans' Affairs   NaN  committee     R
# 29                  House Committee on Ways and Means   NaN  committee     D
# 30                  House Committee on Ways and Means   NaN  committee     R
# 31                      House Committee on the Budget   NaN  committee     D
# 32                      House Committee on the Budget   NaN  committee     R
# 33                   House Committee on the Judiciary   NaN  committee     D
# 34                   House Committee on the Judiciary   NaN  committee     R
# 35                        Joint Committee on Taxation   NaN  committee   N/A
# 36                           Joint Economic Committee   NaN  committee     D
# 37                           Joint Economic Committee   NaN  committee     R
# 38  Senate Committee on Agriculture, Nutrition, an...   NaN  committee     R
# 39                 Senate Committee on Appropriations   NaN  committee     D
# 40                 Senate Committee on Armed Services   NaN  committee     R
# 41  Senate Committee on Banking, Housing, and Urba...   NaN  committee     R
# 42  Senate Committee on Commerce, Science, and Tra...   NaN  committee     R
# 43   Senate Committee on Energy and Natural Resources   NaN  committee     D
# 44   Senate Committee on Energy and Natural Resources   NaN  committee     R
# 45   Senate Committee on Environment and Public Works   NaN  committee     D
# 46   Senate Committee on Environment and Public Works   NaN  committee     R
# 47                        Senate Committee on Finance   NaN  committee     R
# 48  Senate Committee on Health, Education, Labor, ...   NaN  committee     R
# 49                 Senate Committee on Indian Affairs   NaN  committee     R
# 50  Senate Committee on Small Business and Entrepr...   NaN  committee     R
# 51              Senate Committee on Veterans' Affairs   NaN  committee     R
# 52                     Senate Committee on the Budget   NaN  committee     R
# 53                  Senate Committee on the Judiciary   NaN  committee     R
# 54                  Senate Special Committee on Aging   NaN  committee     R
#
#         screen_name  ch
# 0       HouseAgNews  no
# 1       AppropsDems  no
# 2   HouseAppropsGOP  no
# 3     HASCDemocrats  no
# 4   HASCRepublicans  no
# 5   edworkforcedems  no
# 6       EdWorkforce  no
# 7    EnergyCommerce  no
# 8     HouseCommerce  no
# 9           FSCDems  no
# 10    FinancialCmte  no
# 11    HFACDemocrats  no
# 12     HouseForeign  no
# 13     HomelandDems  no
# 14    HouseHomeland  no
# 15    HouseAdm_Dems  no
# 16     HouseAdmnGOP  no
# 17           NRDems  no
# 18     NatResources  no
# 19    OversightDems  no
# 20     GOPoversight  no
# 21        RulesReps  no
# 22      SciCmteDems  no
# 23     HouseScience  no
# 24    HouseSmallBiz  no
# 25    TransportDems  no
# 26        Transport  no
# 27   VetAffairsDems  no
# 28  HouseVetAffairs  no
# 29    WaysMeansCmte  no
# 30  WaysandMeansGOP  no
# 31  HouseBudgetDems  no
# 32   housebudgetGOP  no
# 33     HouseJudDems  no
# 34   HouseJudiciary  no
# 35           jctgov  no
# 36          JECDems  no
# 37   JECRepublicans  no
# 38      SenateAgGOP  no
# 39    SenateApprops  no
# 40     SASCMajority  no
# 41       BankingGOP  no
# 42   SenateCommerce  no
# 43       EnergyDems  no
# 44        EnergyGOP  no
# 45          EPWDems  no
# 46           EPWGOP  no
# 47    GOPSenFinance  no
# 48          GOPHELP  no
# 49  IndianCommittee  no
# 50     SmallBizCmte  no
# 51          VAChair  no
# 52        BudgetGOP  no
# 53     senjudiciary  no
# 54      SenateAging  no

# %%
df7
# Out:
#                     screen_name   ch  \
# 0                BlueCollarDems   no
# 1                 HouseBlueDogs   no
# 2                         CAPAC   no
# 3                   OfficialCBC   no
# 4                  HealthCaucus   no
# 5               ProChoiceCaucus   no
# 6                USProgressives   no
# 7                  gopdoccaucus   no
# 8                HispanicCaucus   no
# 9                 freedomcaucus   no
# 10                conversations   no
# 11                libertycaucus   no
# 12                 LGBTEqCaucus   no
# 13    RepublicanStudy Committee   no
# 14                    LadiesGOP   no
# 15                  repdonyoung   no
# 16                   DonYoungAK  yes
# 17                     RepByrne   no
# 18                 BradleyByrne  yes
# 19              USRepGaryPalmer   no
# 20               Palmer4Alabama  yes
# 21                RepMarthaRoby   no
# 22                     TeamRoby  yes
# 23              RepMikeRogersAL   no
# 24               MikeRogersCamp  yes
# 25                  RepMoBrooks   no
# 26              Robert_Aderholt   no
# 27                 CongAderholt  yes
# 28               RepTerriSewell   no
# 29                 RepWesterman   no
# ...                         ...  ...
# 977                  SenTedCruz   no
# 978                 TeamTedCruz  yes
# 979                     tedcruz  yes
# 980                  SenMikeLee   no
# 981              MikeLeeforUtah  yes
# 982               senorrinhatch   no
# 983                  OrrinHatch  yes
# 984                  MarkWarner   no
# 985              SenKaineOffice   no
# 986                    timkaine   no
# 987                  SenSanders   no
# 988               BernieSanders  yes
# 989                SenatorLeahy   no
# 990                PatrickLeahy  yes
# 991             SenatorCantwell   no
# 992               MariaCantwell  yes
# 993                 PattyMurray   no
# 994              MurrayCampaign  yes
# 995               SenRonJohnson   no
# 996                RonJohnsonWI  yes
# 997              SenatorBaldwin   no
# 998                tammybaldwin  yes
# 999              Sen_JoeManchin   no
# 1000               JoeManchinWV  yes
# 1001                  SenCapito   no
# 1002                CapitoforWV  yes
# 1003            SenJohnBarrasso   no
# 1004             barrassoforwyo  yes
# 1005                SenatorEnzi   no
# 1006                 EnziforWyo  yes
#
#                                                accounts chamber  \
# 0     {u'index': 0, u'office': [{u'screen_name': u'B...   house
# 1     {u'index': 1, u'office': [{u'screen_name': u'H...   house
# 2     {u'index': 2, u'office': [{u'screen_name': u'C...   house
# 3     {u'index': 3, u'office': [{u'screen_name': u'O...   house
# 4     {u'index': 4, u'office': [{u'screen_name': u'H...   house
# 5     {u'index': 5, u'office': [{u'screen_name': u'P...   house
# 6     {u'index': 6, u'office': [{u'screen_name': u'U...   house
# 7     {u'index': 7, u'office': [{u'screen_name': u'g...   house
# 8     {u'index': 8, u'office': [{u'screen_name': u'H...   house
# 9     {u'index': 9, u'office': [{u'screen_name': u'f...   house
# 10    {u'index': 9, u'office': [{u'screen_name': u'f...   house
# 11    {u'index': 10, u'office': [{u'screen_name': u'...   house
# 12    {u'index': 11, u'office': [{u'screen_name': u'...   house
# 13    {u'index': 12, u'office': [{u'screen_name': u'...   house
# 14    {u'index': 13, u'office': [{u'screen_name': u'...   house
# 15    {u'index': 14, u'campaign': [{u'screen_name': ...   house
# 16    {u'index': 14, u'campaign': [{u'screen_name': ...   house
# 17    {u'index': 15, u'campaign': [{u'screen_name': ...   house
# 18    {u'index': 15, u'campaign': [{u'screen_name': ...   house
# 19    {u'index': 16, u'campaign': [{u'screen_name': ...   house
# 20    {u'index': 16, u'campaign': [{u'screen_name': ...   house
# 21    {u'index': 17, u'campaign': [{u'screen_name': ...   house
# 22    {u'index': 17, u'campaign': [{u'screen_name': ...   house
# 23    {u'index': 18, u'campaign': [{u'screen_name': ...   house
# 24    {u'index': 18, u'campaign': [{u'screen_name': ...   house
# 25    {u'index': 19, u'office': [{u'screen_name': u'...   house
# 26    {u'index': 20, u'campaign': [{u'screen_name': ...   house
# 27    {u'index': 20, u'campaign': [{u'screen_name': ...   house
# 28    {u'index': 21, u'office': [{u'screen_name': u'...   house
# 29    {u'index': 22, u'campaign': [{u'screen_name': ...   house
# ...                                                 ...     ...
# 977   {u'index': 537, u'campaign': [{u'screen_name':...  senate
# 978   {u'index': 537, u'campaign': [{u'screen_name':...  senate
# 979   {u'index': 537, u'campaign': [{u'screen_name':...  senate
# 980   {u'index': 538, u'campaign': [{u'screen_name':...  senate
# 981   {u'index': 538, u'campaign': [{u'screen_name':...  senate
# 982   {u'index': 539, u'campaign': [{u'screen_name':...  senate
# 983   {u'index': 539, u'campaign': [{u'screen_name':...  senate
# 984   {u'index': 540, u'office': [{u'screen_name': u...  senate
# 985   {u'index': 541, u'office': [{u'screen_name': u...  senate
# 986   {u'index': 541, u'office': [{u'screen_name': u...  senate
# 987   {u'index': 542, u'campaign': [{u'screen_name':...  senate
# 988   {u'index': 542, u'campaign': [{u'screen_name':...  senate
# 989   {u'index': 543, u'campaign': [{u'screen_name':...  senate
# 990   {u'index': 543, u'campaign': [{u'screen_name':...  senate
# 991   {u'index': 544, u'campaign': [{u'screen_name':...  senate
# 992   {u'index': 544, u'campaign': [{u'screen_name':...  senate
# 993   {u'index': 545, u'campaign': [{u'screen_name':...  senate
# 994   {u'index': 545, u'campaign': [{u'screen_name':...  senate
# 995   {u'index': 546, u'campaign': [{u'screen_name':...  senate
# 996   {u'index': 546, u'campaign': [{u'screen_name':...  senate
# 997   {u'index': 547, u'campaign': [{u'screen_name':...  senate
# 998   {u'index': 547, u'campaign': [{u'screen_name':...  senate
# 999   {u'index': 548, u'campaign': [{u'screen_name':...  senate
# 1000  {u'index': 548, u'campaign': [{u'screen_name':...  senate
# 1001  {u'index': 549, u'campaign': [{u'screen_name':...  senate
# 1002  {u'index': 549, u'campaign': [{u'screen_name':...  senate
# 1003  {u'index': 550, u'campaign': [{u'screen_name':...  senate
# 1004  {u'index': 550, u'campaign': [{u'screen_name':...  senate
# 1005  {u'index': 551, u'campaign': [{u'screen_name':...  senate
# 1006  {u'index': 551, u'campaign': [{u'screen_name':...  senate
#
#                                                   id  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
# 10                                               NaN
# 11                                               NaN
# 12                                               NaN
# 13                                               NaN
# 14                                               NaN
# 15    {u'bioguide': u'Y000033', u'govtrack': 400440}
# 16    {u'bioguide': u'Y000033', u'govtrack': 400440}
# 17    {u'bioguide': u'B001289', u'govtrack': 412601}
# 18    {u'bioguide': u'B001289', u'govtrack': 412601}
# 19    {u'bioguide': u'P000609', u'govtrack': 412608}
# 20    {u'bioguide': u'P000609', u'govtrack': 412608}
# 21    {u'bioguide': u'R000591', u'govtrack': 412394}
# 22    {u'bioguide': u'R000591', u'govtrack': 412394}
# 23    {u'bioguide': u'R000575', u'govtrack': 400341}
# 24    {u'bioguide': u'R000575', u'govtrack': 400341}
# 25    {u'bioguide': u'B001274', u'govtrack': 412395}
# 26    {u'bioguide': u'A000055', u'govtrack': 400004}
# 27    {u'bioguide': u'A000055', u'govtrack': 400004}
# 28    {u'bioguide': u'S001185', u'govtrack': 412396}
# 29    {u'bioguide': u'W000821', u'govtrack': 412610}
# ...                                              ...
# 977   {u'bioguide': u'C001098', u'govtrack': 412573}
# 978   {u'bioguide': u'C001098', u'govtrack': 412573}
# 979   {u'bioguide': u'C001098', u'govtrack': 412573}
# 980   {u'bioguide': u'L000577', u'govtrack': 412495}
# 981   {u'bioguide': u'L000577', u'govtrack': 412495}
# 982   {u'bioguide': u'H000338', u'govtrack': 300052}
# 983   {u'bioguide': u'H000338', u'govtrack': 300052}
# 984   {u'bioguide': u'W000805', u'govtrack': 412321}
# 985   {u'bioguide': u'K000384', u'govtrack': 412582}
# 986   {u'bioguide': u'K000384', u'govtrack': 412582}
# 987   {u'bioguide': u'S000033', u'govtrack': 400357}
# 988   {u'bioguide': u'S000033', u'govtrack': 400357}
# 989   {u'bioguide': u'L000174', u'govtrack': 300065}
# 990   {u'bioguide': u'L000174', u'govtrack': 300065}
# 991   {u'bioguide': u'C000127', u'govtrack': 300018}
# 992   {u'bioguide': u'C000127', u'govtrack': 300018}
# 993   {u'bioguide': u'M001111', u'govtrack': 300076}
# 994   {u'bioguide': u'M001111', u'govtrack': 300076}
# 995   {u'bioguide': u'J000293', u'govtrack': 412496}
# 996   {u'bioguide': u'J000293', u'govtrack': 412496}
# 997   {u'bioguide': u'B001230', u'govtrack': 400013}
# 998   {u'bioguide': u'B001230', u'govtrack': 400013}
# 999   {u'bioguide': u'M001183', u'govtrack': 412391}
# 1000  {u'bioguide': u'M001183', u'govtrack': 412391}
# 1001  {u'bioguide': u'C001047', u'govtrack': 400061}
# 1002  {u'bioguide': u'C001047', u'govtrack': 400061}
# 1003  {u'bioguide': u'B001261', u'govtrack': 412251}
# 1004  {u'bioguide': u'B001261', u'govtrack': 412251}
# 1005  {u'bioguide': u'E000285', u'govtrack': 300041}
# 1006  {u'bioguide': u'E000285', u'govtrack': 300041}
#
#                                              name party state    type
# 0                              Blue Collar Caucus     D   NaN  caucus
# 1                              Blue Dog Coalition     D   NaN  caucus
# 2     Congressional Asian Pacific American Caucus     D   NaN  caucus
# 3                      Congressional Black Caucus     D   NaN  caucus
# 4                     Congressional Health Caucus     R   NaN  caucus
# 5                 Congressional Pro-Choice Caucus     D   NaN  caucus
# 6                Congressional Progressive Caucus     D   NaN  caucus
# 7                              GOP Doctors Caucus     R   NaN  caucus
# 8                                 Hispanic Caucus     D   NaN  caucus
# 9                            House Freedom Caucus     R   NaN  caucus
# 10                           House Freedom Caucus     R   NaN  caucus
# 11                           House Liberty Caucus     R   NaN  caucus
# 12                           LGBT Equality Caucus     D   NaN  caucus
# 13                               Republican Study     R   NaN  caucus
# 14            Republican Women's Policy Committee     R   NaN  caucus
# 15                                      Don Young     R    AK  member
# 16                                      Don Young     R    AK  member
# 17                                  Bradley Byrne     R    AL  member
# 18                                  Bradley Byrne     R    AL  member
# 19                                    Gary Palmer     R    AL  member
# 20                                    Gary Palmer     R    AL  member
# 21                                    Martha Roby     R    AL  member
# 22                                    Martha Roby     R    AL  member
# 23                                    Mike Rogers     R    AL  member
# 24                                    Mike Rogers     R    AL  member
# 25                                      Mo Brooks     R    AL  member
# 26                                Robert Aderholt     R    AL  member
# 27                                Robert Aderholt     R    AL  member
# 28                                   Terri Sewell     D    AL  member
# 29                                Bruce Westerman     R    AR  member
# ...                                           ...   ...   ...     ...
# 977                                      Ted Cruz     R    TX  member
# 978                                      Ted Cruz     R    TX  member
# 979                                      Ted Cruz     R    TX  member
# 980                                      Mike Lee     R    UT  member
# 981                                      Mike Lee     R    UT  member
# 982                                   Orrin Hatch     R    UT  member
# 983                                   Orrin Hatch     R    UT  member
# 984                                   Mark Warner     D    VA  member
# 985                                     Tim Kaine     D    VA  member
# 986                                     Tim Kaine     D    VA  member
# 987                                Bernie Sanders     I    VT  member
# 988                                Bernie Sanders     I    VT  member
# 989                                 Patrick Leahy     D    VT  member
# 990                                 Patrick Leahy     D    VT  member
# 991                                Maria Cantwell     D    WA  member
# 992                                Maria Cantwell     D    WA  member
# 993                                  Patty Murray     D    WA  member
# 994                                  Patty Murray     D    WA  member
# 995                                   Ron Johnson     R    WI  member
# 996                                   Ron Johnson     R    WI  member
# 997                                 Tammy Baldwin     D    WI  member
# 998                                 Tammy Baldwin     D    WI  member
# 999                                   Joe Manchin     D    WV  member
# 1000                                  Joe Manchin     D    WV  member
# 1001                         Shelley Moore Capito     R    WV  member
# 1002                         Shelley Moore Capito     R    WV  member
# 1003                                John Barrasso     R    WY  member
# 1004                                John Barrasso     R    WY  member
# 1005                                    Mike Enzi     R    WY  member
# 1006                                    Mike Enzi     R    WY  member
#
# [1007 rows x 9 columns]

# %%
final = pd.concat([df7, df1, party])

# %%
final.head()
# Out:
#                                             accounts  ch chamber   id  \
# 0  {u'index': 0, u'office': [{u'screen_name': u'B...  no   house  NaN
# 1  {u'index': 1, u'office': [{u'screen_name': u'H...  no   house  NaN
# 2  {u'index': 2, u'office': [{u'screen_name': u'C...  no   house  NaN
# 3  {u'index': 3, u'office': [{u'screen_name': u'O...  no   house  NaN
# 4  {u'index': 4, u'office': [{u'screen_name': u'H...  no   house  NaN
#
#                                           name party     screen_name state  \
# 0                           Blue Collar Caucus     D  BlueCollarDems   NaN
# 1                           Blue Dog Coalition     D   HouseBlueDogs   NaN
# 2  Congressional Asian Pacific American Caucus     D           CAPAC   NaN
# 3                   Congressional Black Caucus     D     OfficialCBC   NaN
# 4                  Congressional Health Caucus     R    HealthCaucus   NaN
#
#      type
# 0  caucus
# 1  caucus
# 2  caucus
# 3  caucus
# 4  caucus

# %%
final.shape
# Out:
# (1077, 9)

# %%
final.to_csv("split_meta.csv", encoding='utf-8')
